# %% [markdown]
# # Lista 9 - LIMITAÇÕES DA LINGUAGEM DA LÓGICA PROPOSICIONAL

# %% [markdown]
# ## Primeiro instalei e importei as bibliotecas necessárias

# %%
# !pip install z3-solver

# %%
from z3 import *

# %% [markdown]
# # Agora começarei a traduzir o problema em Lógica Proposicional.

# %%
# CADA CASA SÓ TEM UMA COR:

# Para a casa 1:

C1Vr = Bool('C1Vr') # A cor da casa1 é vermelha
C1Vd = Bool('C1Vd') # A cor da casa1 é verde
C1M  = Bool('C1M')  # A cor da casa1 é marfim
C1Am = Bool('C1Am') # A cor da casa1 é amarelo
C1Az = Bool('C1Az') # A cor da casa1 é azul

# Para a casa 2:

C2Vr = Bool('C2Vr') # A cor da casa2 é vermelha
C2Vd = Bool('C2Vd') # A cor da casa2 é verde
C2M  = Bool('C2M')  # A cor da casa2 é marfim
C2Am = Bool('C2Am') # A cor da casa2 é amarelo
C2Az = Bool('C2Az') # A cor da casa2 é azul

# Para a casa 3:

C3Vr = Bool('C3Vr') # A cor da casa3 é vermelha
C3Vd = Bool('C3Vd') # A cor da casa3 é verde
C3M  = Bool('C3M')  # A cor da casa3 é marfim
C3Am = Bool('C3Am') # A cor da casa3 é amarelo
C3Az = Bool('C3Az') # A cor da casa3 é azul

# Para a casa 4:

C4Vr = Bool('C4Vr') # A cor da casa4 é vermelha
C4Vd = Bool('C4Vd') # A cor da casa4 é verde
C4M  = Bool('C4M')  # A cor da casa4 é marfim
C4Am = Bool('C4Am') # A cor da casa4 é amarelo
C4Az = Bool('C4Az') # A cor da casa4 é azul

# Para a casa 5:

C5Vr = Bool('C5Vr') # A cor da casa5 é vermelha
C5Vd = Bool('C5Vd') # A cor da casa5 é verde
C5M  = Bool('C5M')  # A cor da casa5 é marfim
C5Am = Bool('C5Am') # A cor da casa5 é amarelo
C5Az = Bool('C5Az') # A cor da casa5 é azul

# CADA CASA TEM UM MORADOR COM UMA NACIONALIDADE DIFERENTE

# Para a casa 1:

C1S = Bool('C1S') # O morador da casa1 é um Surinâmes
C1Es = Bool('C1Es') # O morador da casa1 é um Espanhol
C1Eq  = Bool('C1Eq')  # O morador da casa1 é um Equatoriano
C1N = Bool('C1N') # O morador da casa1 é um Norueguês
C1J = Bool('C1J') # O morador da casa1 é um Japônes

# Para a casa 2:

C2S = Bool('C2S') # O morador da casa2 é um Surinâmes
C2Es = Bool('C2Es') # O morador da casa2 é um Espanhol
C2Eq  = Bool('C2Eq')  # O morador da casa2 é um Equatoriano
C2N = Bool('C2N') # O morador da casa2 é um Norueguês
C2J = Bool('C2J') # O morador da casa2 é um Japônes

# Para a casa 3:

C3S = Bool('C3S') # O morador da casa3 é um Surinâmes
C3Es = Bool('C3Es') # O morador da casa3 é um Espanhol
C3Eq  = Bool('C3Eq')  # O morador da casa3 é um Equatoriano
C3N = Bool('C3N') # O morador da casa3 é um Norueguês
C3J = Bool('C3J') # O morador da casa3 é um Japônes

# Para a casa 4:

C4S = Bool('C4S') # O morador da casa4 é um Surinâmes
C4Es = Bool('C4Es') # O morador da casa4 é um Espanhol
C4Eq  = Bool('C4Eq')  # O morador da casa4 é um Equatoriano
C4N = Bool('C4N') # O morador da casa4 é um Norueguês
C4J = Bool('C4J') # O morador da casa4 é um Japônes

# Para a casa 5:

C5S = Bool('C5S') # O morador da casa5 é um Surinâmes
C5Es = Bool('C5Es') # O morador da casa5 é um Espanhol
C5Eq  = Bool('C5Eq')  # O morador da casa5 é um Equatoriano
C5N = Bool('C5N') # O morador da casa5 é um Norueguês
C5J = Bool('C5J') # O morador da casa5 é um Japônes

# CADA CASA TEM UM ANIMAL DIFERENTE:

# Para a casa 1:

C1C = Bool('C1C') # O animal da casa1 é um Cachorro
C1Esq = Bool('C1Esq') # O animal da casa1 é um Esquilo
C1R  = Bool('C1R')  # O animal da casa1 é uma Raposa
C1T = Bool('C1T') # O animal da casa1 é um Tucano
C1Ca = Bool('C1Ca') # O animal da casa1 é um Cavalo

# Para a casa 2:

C2C = Bool('C2C') # O animal da casa2 é um Cachorro
C2Esq = Bool('C2Esq') # O animal da casa2 é um Esquilo
C2R  = Bool('C2R')  # O animal da casa2 é uma Raposa
C2T = Bool('C2T') # O animal da casa2 é um Tucano
C2Ca = Bool('C2Ca') # O animal da casa2 é um Cavalo

# Para a casa 3:

C3C = Bool('C3C') # O animal da casa3 é um Cachorro
C3Esq = Bool('C3Esq') # O animal da casa3 é um Esquilo
C3R  = Bool('C3R')  # O animal da casa3 é uma Raposa
C3T = Bool('C3T') # O animal da casa3 é um Tucano
C3Ca = Bool('C3Ca') # O animal da casa3 é um Cavalo

# Para a casa 4:

C4C = Bool('C4C') # O animal da casa4 é um Cachorro
C4Esq = Bool('C4Esq') # O animal da casa4 é um Esquilo
C4R  = Bool('C4R')  # O animal da casa4 é uma Raposa
C4T = Bool('C4T') # O animal da casa4 é um Tucano
C4Ca = Bool('C4Ca') # O animal da casa4 é um Cavalo

# Para a casa 5:

C5C = Bool('C5C') # O animal da casa5 é um Cachorro
C5Esq = Bool('C5Esq') # O animal da casa5 é um Esquilo
C5R  = Bool('C5R')  # O animal da casa5 é uma Raposa
C5T = Bool('C5T') # O animal da casa5 é um Tucano
C5Ca = Bool('C5Ca') # O animal da casa5 é um Cavalo

# EM CADA CASA O SEU MORADOR TOMA UMA BEBIDA DIFERENTE

# Para a casa 1:

C1Cf = Bool('C1Cf') # A bebida tomada na casa1 é Café
C1LE = Bool('C1LE') # A bebida tomada na casa1 é Leite
C1La  = Bool('C1La')  # A bebida tomada na casa1 é Laranja
C1Ch = Bool('C1Ch') # A bebida tomada na casa1 é Chá
C1Ag = Bool('C1Ag') # A bebida tomada na casa1 é Água

# Para a casa 2:

C2Cf = Bool('C2Cf') # A bebida tomada na casa2 é Café
C2LE = Bool('C2LE') # A bebida tomada na casa2 é Leite
C2La  = Bool('C2La')  # A bebida tomada na casa2 é Laranja
C2Ch = Bool('C2Ch') # A bebida tomada na casa2 é Chá
C2Ag = Bool('C2Ag') # A bebida tomada na casa2 é Água

# Para a casa 3:

C3Cf = Bool('C3Cf') # A bebida tomada na casa3 é Café
C3LE = Bool('C3LE') # A bebida tomada na casa3 é Leite
C3La  = Bool('C3La')  # A bebida tomada na casa3 é Laranja
C3Ch = Bool('C3Ch') # A bebida tomada na casa3 é Chá
C3Ag = Bool('C3Ag') # A bebida tomada na casa3 é Água

# Para a casa 4:

C4Cf = Bool('C4Cf') # A bebida tomada na casa1 é Café
C4LE = Bool('C4LE') # A bebida tomada na casa1 é Leite
C4La  = Bool('C4La')  # A bebida tomada na casa1 é Laranja
C4Ch = Bool('C4Ch') # A bebida tomada na casa1 é Chá
C4Ag = Bool('C4Ag') # A bebida tomada na casa1 é Água

# Para a casa 5:

C5Cf = Bool('C5Cf') # A bebida tomada na casa5 é Café
C5LE = Bool('C5LE') # A bebida tomada na casa5 é Leite
C5La  = Bool('C5La')  # A bebida tomada na casa5 é Laranja
C5Ch = Bool('C5Ch') # A bebida tomada na casa5 é Chá
C5Ag = Bool('C5Ag') # A bebida tomada na casa5 é Água

# O INSTRUMENTO TOCADO EM CADA CASAS É:

# Para a casa 1:

C1Sa = Bool('C1Sa') # O instrumento tocado na casa1 é Saxofone
C1Vi = Bool('C1Vi') # O instrumento tocado na casa1 é Violino
C1Pi  = Bool('C1Pi')  # O instrumento tocado na casa1 é Piano
C1Ob = Bool('C1Ob') # O instrumento tocado na casa1 é Oboé
C1At = Bool('C1At') # O instrumento tocado na casa1 é Atabaques

# Para a casa 2:

C2Sa = Bool('C2Sa') # O instrumento tocado na casa2 é Saxofone
C2Vi = Bool('C2Vi') # O instrumento tocado na casa2 é Violino
C2Pi  = Bool('C2Pi')  # O instrumento tocado na casa2 é Piano
C2Ob = Bool('C2Ob') # O instrumento tocado na casa2 é Oboé
C2At = Bool('C2At') # O instrumento tocado na casa2 é Atabaques

# Para a casa 3:

C3Sa = Bool('C3Sa') # O instrumento tocado na casa3 é Saxofone
C3Vi = Bool('C3Vi') # O instrumento tocado na casa3 é Violino
C3Pi  = Bool('C3Pi')  # O instrumento tocado na casa3 é Piano
C3Ob = Bool('C3Ob') # O instrumento tocado na casa3 é Oboé
C3At = Bool('C3At') # O instrumento tocado na casa3 é Atabaques

# Para a casa 4:

C4Sa = Bool('C4Sa') # O instrumento tocado na casa4 é Saxofone
C4Vi = Bool('C4Vi') # O instrumento tocado na casa4 é Violino
C4Pi  = Bool('C4Pi')  # O instrumento tocado na casa4 é Piano
C4Ob = Bool('C4Ob') # O instrumento tocado na casa4 é Oboé
C4At = Bool('C4At') # O instrumento tocado na casa4 é Atabaques

# Para a casa 5:

C5Sa = Bool('C5Sa') # O instrumento tocado na casa5 é Saxofone
C5Vi = Bool('C5Vi') # O instrumento tocado na casa5 é Violino
C5Pi  = Bool('C5Pi')  # O instrumento tocado na casa5 é Piano
C5Ob = Bool('C5Ob') # O instrumento tocado na casa5 é Oboé
C5At = Bool('C5At') # O instrumento tocado na casa5 é Atabaques

# CADA CASA SÓ TEM UMA COR

f1 = Or([And([C1Vr, Not(C1Vd), Not(C1M), Not(C1Am), Not(C1Az)]),And([Not(C1Vr), C1Vd, Not(C1M), Not(C1Am), Not(C1Az)]),And([Not(C1Vr), Not(C1Vd), C1M, Not(C1Am), Not(C1Az)]),And([Not(C1Vr), Not(C1Vd), Not(C1M), C1Am, Not(C1Az)]),And([Not(C1Vr), Not(C1Vd), Not(C1M), Not(C1Am), C1Az])])
f2 = Or([And([C2Vr, Not(C2Vd), Not(C2M), Not(C2Am), Not(C2Az)]),And([Not(C2Vr), C2Vd, Not(C2M), Not(C2Am), Not(C2Az)]),And([Not(C2Vr), Not(C2Vd), C2M, Not(C2Am), Not(C2Az)]),And([Not(C2Vr), Not(C2Vd), Not(C2M), C2Am, Not(C2Az)]),And([Not(C2Vr), Not(C2Vd), Not(C2M), Not(C2Am), C2Az])])
f3 = Or([And([C3Vr, Not(C3Vd), Not(C3M), Not(C3Am), Not(C3Az)]),And([Not(C3Vr), C3Vd, Not(C3M), Not(C3Am), Not(C3Az)]),And([Not(C3Vr), Not(C3Vd), C3M, Not(C3Am), Not(C3Az)]),And([Not(C3Vr), Not(C3Vd), Not(C3M), C3Am, Not(C3Az)]),And([Not(C3Vr), Not(C3Vd), Not(C3M), Not(C3Am), C3Az])])
f4 = Or([And([C4Vr, Not(C4Vd), Not(C4M), Not(C4Am), Not(C4Az)]),And([Not(C4Vr), C4Vd, Not(C4M), Not(C4Am), Not(C4Az)]),And([Not(C4Vr), Not(C4Vd), C4M, Not(C4Am), Not(C4Az)]),And([Not(C4Vr), Not(C4Vd), Not(C4M), C4Am, Not(C4Az)]),And([Not(C4Vr), Not(C4Vd), Not(C4M), Not(C4Am), C4Az])])
f5 = Or([And([C5Vr, Not(C5Vd), Not(C5M), Not(C5Am), Not(C5Az)]),And([Not(C5Vr), C5Vd, Not(C5M), Not(C5Am), Not(C5Az)]),And([Not(C5Vr), Not(C5Vd), C5M, Not(C5Am), Not(C5Az)]),And([Not(C5Vr), Not(C5Vd), Not(C5M), C5Am, Not(C5Az)]),And([Not(C5Vr), Not(C5Vd), Not(C5M), Not(C5Am), C5Az])])

# CADA CASA TEM UM MORADOR DE UMA NACIONALIDADE

f6 = Or([And([C1S, Not(C1Es), Not(C1Eq), Not(C1N), Not(C1J)]),And([Not(C1S), C1Es, Not(C1Eq), Not(C1N), Not(C1J)]),And([Not(C1S), Not(C1Es), C1Eq, Not(C1N), Not(C1J)]),And([Not(C1S), Not(C1Es), Not(C1Eq), C1N, Not(C1J)]),And([Not(C1S), Not(C1Es), Not(C1Eq), Not(C1N), C1J])])
f7 = Or([And([C2S, Not(C2Es), Not(C2Eq), Not(C2N), Not(C2J)]),And([Not(C2S), C2Es, Not(C2Eq), Not(C2N), Not(C2J)]),And([Not(C2S), Not(C2Es), C2Eq, Not(C2N), Not(C2J)]),And([Not(C2S), Not(C2Es), Not(C2Eq), C2N, Not(C2J)]),And([Not(C2S), Not(C2Es), Not(C2Eq), Not(C2N), C2J])])
f8 = Or([And([C3S, Not(C3Es), Not(C3Eq), Not(C3N), Not(C3J)]),And([Not(C3S), C3Es, Not(C3Eq), Not(C3N), Not(C3J)]),And([Not(C3S), Not(C3Es), C3Eq, Not(C3N), Not(C3J)]),And([Not(C3S), Not(C3Es), Not(C3Eq), C3N, Not(C3J)]),And([Not(C3S), Not(C3Es), Not(C3Eq), Not(C3N), C3J])])
f9 = Or([And([C4S, Not(C4Es), Not(C4Eq), Not(C4N), Not(C4J)]),And([Not(C4S), C4Es, Not(C4Eq), Not(C4N), Not(C4J)]),And([Not(C4S), Not(C4Es), C4Eq, Not(C4N), Not(C4J)]),And([Not(C4S), Not(C4Es), Not(C4Eq), C4N, Not(C4J)]),And([Not(C4S), Not(C4Es), Not(C4Eq), Not(C4N), C4J])])
f10 = Or([And([C5S, Not(C5Es), Not(C5Eq), Not(C5N), Not(C5J)]),And([Not(C5S), C5Es, Not(C5Eq), Not(C5N), Not(C5J)]),And([Not(C5S), Not(C5Es), C5Eq, Not(C5N), Not(C5J)]),And([Not(C5S), Not(C5Es), Not(C5Eq), C5N, Not(C5J)]),And([Not(C5S), Not(C5Es), Not(C5Eq), Not(C5N), C5J])])

# CADA CASA TEM SÓ UM ANIMAL

f11 = Or([And([C1C, Not(C1Esq), Not(C1R), Not(C1T), Not(C1Ca)]),And([Not(C1C), C1Esq, Not(C1R), Not(C1T), Not(C1Ca)]),And([Not(C1C), Not(C1Esq), C1R, Not(C1T), Not(C1Ca)]),And([Not(C1C), Not(C1Esq), Not(C1R), C1T, Not(C1Ca)]),And([Not(C1C), Not(C1Esq), Not(C1R), Not(C1T), C1Ca])])
f12 = Or([And([C2C, Not(C2Esq), Not(C2R), Not(C2T), Not(C2Ca)]),And([Not(C2C), C2Esq, Not(C2R), Not(C2T), Not(C2Ca)]),And([Not(C2C), Not(C2Esq), C2R, Not(C2T), Not(C2Ca)]),And([Not(C2C), Not(C2Esq), Not(C2R), C2T, Not(C2Ca)]),And([Not(C2C), Not(C2Esq), Not(C2R), Not(C2T), C2Ca])])
f13 = Or([And([C3C, Not(C3Esq), Not(C3R), Not(C3T), Not(C3Ca)]),And([Not(C3C), C3Esq, Not(C3R), Not(C3T), Not(C3Ca)]),And([Not(C3C), Not(C3Esq), C3R, Not(C3T), Not(C3Ca)]),And([Not(C3C), Not(C3Esq), Not(C3R), C3T, Not(C3Ca)]),And([Not(C3C), Not(C3Esq), Not(C3R), Not(C3T), C3Ca])])
f14 = Or([And([C4C, Not(C4Esq), Not(C4R), Not(C4T), Not(C4Ca)]),And([Not(C4C), C4Esq, Not(C4R), Not(C4T), Not(C4Ca)]),And([Not(C4C), Not(C4Esq), C4R, Not(C4T), Not(C4Ca)]),And([Not(C4C), Not(C4Esq), Not(C4R), C4T, Not(C4Ca)]),And([Not(C4C), Not(C4Esq), Not(C4R), Not(C4T), C4Ca])])
f15 = Or([And([C5C, Not(C5Esq), Not(C5R), Not(C5T), Not(C5Ca)]),And([Not(C5C), C5Esq, Not(C5R), Not(C5T), Not(C5Ca)]),And([Not(C5C), Not(C5Esq), C5R, Not(C5T), Not(C5Ca)]),And([Not(C5C), Not(C5Esq), Not(C5R), C5T, Not(C5Ca)]),And([Not(C5C), Not(C5Esq), Not(C5R), Not(C5T), C5Ca])])

# CADA CASA O MORADOR BEBE UMA SÓ TIPO DE BEBIDA

f16 = Or([And([C1Cf, Not(C1LE), Not(C1La), Not(C1Ch), Not(C1Ag)]),And([Not(C1Cf), C1LE, Not(C1La), Not(C1Ch), Not(C1Ag)]),And([Not(C1Cf), Not(C1LE), C1La, Not(C1Ch), Not(C1Ag)]),And([Not(C1Cf), Not(C1LE), Not(C1La), C1Ch, Not(C1Ag)]),And([Not(C1Cf), Not(C1LE), Not(C1La), Not(C1Ch),C1Ag])])
f17 = Or([And([C2Cf, Not(C2LE), Not(C2La), Not(C2Ch), Not(C2Ag)]),And([Not(C2Cf), C2LE, Not(C2La), Not(C2Ch), Not(C2Ag)]),And([Not(C2Cf), Not(C2LE), C2La, Not(C2Ch), Not(C2Ag)]),And([Not(C2Cf), Not(C2LE), Not(C2La), C2Ch, Not(C2Ag)]),And([Not(C2Cf), Not(C2LE), Not(C2La), Not(C2Ch),C2Ag])])
f18 = Or([And([C3Cf, Not(C3LE), Not(C3La), Not(C3Ch), Not(C3Ag)]),And([Not(C3Cf), C3LE, Not(C3La), Not(C3Ch), Not(C3Ag)]),And([Not(C3Cf), Not(C3LE), C3La, Not(C3Ch), Not(C3Ag)]),And([Not(C3Cf), Not(C3LE), Not(C3La), C3Ch, Not(C3Ag)]),And([Not(C3Cf), Not(C3LE), Not(C3La), Not(C3Ch),C3Ag])])
f19 = Or([And([C4Cf, Not(C4LE), Not(C4La), Not(C4Ch), Not(C4Ag)]),And([Not(C4Cf), C4LE, Not(C4La), Not(C4Ch), Not(C4Ag)]),And([Not(C4Cf), Not(C4LE), C4La, Not(C4Ch), Not(C4Ag)]),And([Not(C4Cf), Not(C4LE), Not(C4La), C4Ch, Not(C4Ag)]),And([Not(C4Cf), Not(C4LE), Not(C4La), Not(C4Ch),C4Ag])])
f20 = Or([And([C5Cf, Not(C5LE), Not(C5La), Not(C5Ch), Not(C5Ag)]),And([Not(C5Cf), C5LE, Not(C5La), Not(C5Ch), Not(C5Ag)]),And([Not(C5Cf), Not(C5LE), C5La, Not(C5Ch), Not(C5Ag)]),And([Not(C5Cf), Not(C5LE), Not(C5La), C5Ch, Not(C5Ag)]),And([Not(C5Cf), Not(C5LE), Not(C5La), Not(C5Ch),C5Ag])])

# CADA CASA O MORADOR TOCA UM SÓ INSTRUMENTO

f21 = Or([And([C1Sa, Not(C1Vi), Not(C1Pi), Not(C1Ob), Not(C1At)]),And([Not(C1Sa), C1Vi, Not(C1Pi), Not(C1Ob), Not(C1At)]),And([Not(C1Sa), Not(C1Vi), C1Pi, Not(C1Ob), Not(C1At)]),And([Not(C1Sa), Not(C1Vi), Not(C1Pi),C1Ob, Not(C1At)]),And([Not(C1Sa), Not(C1Vi), Not(C1Pi), Not(C1Ob), C1At])])
f22 = Or([And([C2Sa, Not(C2Vi), Not(C2Pi), Not(C2Ob), Not(C2At)]),And([Not(C2Sa), C2Vi, Not(C2Pi), Not(C2Ob), Not(C2At)]),And([Not(C2Sa), Not(C2Vi), C2Pi, Not(C2Ob), Not(C2At)]),And([Not(C2Sa), Not(C2Vi), Not(C2Pi),C2Ob, Not(C2At)]),And([Not(C2Sa), Not(C2Vi), Not(C2Pi), Not(C2Ob), C2At])])
f23 = Or([And([C3Sa, Not(C3Vi), Not(C3Pi), Not(C3Ob), Not(C3At)]),And([Not(C3Sa), C3Vi, Not(C3Pi), Not(C3Ob), Not(C3At)]),And([Not(C3Sa), Not(C3Vi), C3Pi, Not(C3Ob), Not(C3At)]),And([Not(C3Sa), Not(C3Vi), Not(C3Pi),C3Ob, Not(C3At)]),And([Not(C3Sa), Not(C3Vi), Not(C3Pi), Not(C3Ob), C3At])])
f24 = Or([And([C4Sa, Not(C4Vi), Not(C4Pi), Not(C4Ob), Not(C4At)]),And([Not(C4Sa), C4Vi, Not(C4Pi), Not(C4Ob), Not(C4At)]),And([Not(C4Sa), Not(C4Vi), C4Pi, Not(C4Ob), Not(C4At)]),And([Not(C4Sa), Not(C4Vi), Not(C4Pi),C4Ob, Not(C4At)]),And([Not(C4Sa), Not(C4Vi), Not(C4Pi), Not(C4Ob), C4At])])
f25 = Or([And([C5Sa, Not(C5Vi), Not(C5Pi), Not(C5Ob), Not(C5At)]),And([Not(C5Sa), C5Vi, Not(C5Pi), Not(C5Ob), Not(C5At)]),And([Not(C5Sa), Not(C5Vi), C5Pi, Not(C5Ob), Not(C5At)]),And([Not(C5Sa), Not(C5Vi), Not(C5Pi),C5Ob, Not(C5At)]),And([Not(C5Sa), Not(C5Vi), Not(C5Pi), Not(C5Ob), C5At])])

# O surinamês mora na casa vermelha.

f26 = Or([And([C1S, C1Vr]),And([C2S, C2Vr]),And([C3S, C3Vr]),And([C4S, C4Vr]),And([C5S, C5Vr])])

# O espanhol é dono de um cachorro.

f27 = Or([And([C1C, C1Es]),And([C2C, C2Es]),And([C3C, C3Es]),And([C4C, C4Es]),And([C5C, C5Es])])

# Café é bebido na casa verde

f28 = Or([And([C1Vd, C1Cf]),And([C2Vd, C2Cf]),And([C3Vd, C3Cf]),And([C4Vd, C4Cf]),And([C5Vd, C5Cf])])

# O equatoriano bebe chá.

f29 = Or([And([C1Ch, C1Eq]),And([C2Ch, C2Eq]),And([C3Ch, C3Eq]),And([C4Ch, C4Eq]),And([C5Ch, C5Eq])])

# A casa verde é imediatamente à direita da casa cor de marfim

f30 = Or([And([C1M, C2Vd]),And([C2M, C3Vd]),And([C3M, C4Vd]),And([C4M, C5Vd])])

# O violinista é dono de um esquilo.

f31 = Or([And([C1Esq, C1Vi]),And([C2Esq, C2Vi]),And([C3Esq, C3Vi]),And([C4Esq, C4Vi]),And([C5Esq, C5Vi])])

# Um piano é tocado na casa amarela

f32 = Or([And([C1Pi, C1Am]),And([C2Pi, C2Am]),And([C3Pi, C3Am]),And([C4Pi, C4Am]),And([C5Pi, C5Am])])

# Leite é bebido na casa do meio.

f33 = Or([C3LE])

# O norueguês mora na primeira casa

f34 = Or([C1N])

# A pessoa que toca oboé mora na casa vizinha a da pessoa que tem uma raposa.

f35 = Or([And([C1R, C2Ob]),And([C2R, C3Ob]),And([C2R, C1Ob]),And([C3R, C2Ob]),And([C3R, C4Ob]),And([C4R, C3Ob]),And([C4R, C5Ob]),And([C5R, C4Ob])])

# Atabaques são tocados na casa vizinha aonde um cavalo é criado.

f36 = Or([And([C1Ca, C2At]),And([C2Ca, C3At]),And([C2Ca, C1At]),And([C3Ca, C2At]),And([C3Ca, C4At]),And([C4Ca, C3At]),And([C4Ca, C5At]),And([C5Ca, C4At])])

# O contrabaixista bebe suco de laranja.

f37 = Or([And([C1Vi, C1La]),And([C2Vi, C2La]),And([C3Vi, C3La]),And([C4Vi, C4La]),And([C5Vi, C5La])])

# O japonês toca saxofone.

f38 = Or([And([C1Sa, C1J]),And([C2Sa, C2J]),And([C3Sa, C3J]),And([C4Sa, C4J]),And([C5Sa, C5J])])

# O norueguês mora na casa vizinha à casa azul.

f39 = Or([And([C1Az, C2N]),And([C2Az, C1N]),And([C2Az, C3N]),And([C3Az, C2N]),And([C3Az, C4N]),And([C4Az, C3N]),And([C4Az, C5N]),And([C5Az, C4N])])

# CADA COR SÓ PODE APARECER APENAS UMA VEZ:

f40 = Or([And([C1Vr, Not(C2Vr), Not(C3Vr), Not(C4Vr), Not(C5Vr)]),And([Not(C1Vr), C2Vr, Not(C3Vr), Not(C4Vr), Not(C5Vr)]),And([Not(C1Vr), Not(C2Vr),C3Vr, Not(C4Vr), Not(C5Vr)]),And([Not(C1Vr), Not(C2Vr), Not(C3Vr),C4Vr, Not(C5Vr)]),And([Not(C1Vr), Not(C2Vr), Not(C3Vr), Not(C4Vr), C5Vr])])
f41 = Or([And([C1Vd, Not(C2Vd), Not(C3Vd), Not(C4Vd), Not(C5Vd)]),And([Not(C1Vd), C2Vd, Not(C3Vd), Not(C4Vd), Not(C5Vd)]),And([Not(C1Vd), Not(C2Vd), C3Vd, Not(C4Vd), Not(C5Vd)]),And([Not(C1Vd), Not(C2Vd), Not(C3Vd), C4Vd, Not(C5Vd)]),And([Not(C1Vd), Not(C2Vd), Not(C3Vd), Not(C4Vd), C5Vd])])
f42 = Or([And([C1M, Not(C2M), Not(C3M), Not(C4M), Not(C5M)]),And([Not(C1M), C2M, Not(C3M), Not(C4M), Not(C5M)]),And([Not(C1M), Not(C2M), C3M, Not(C4M), Not(C5M)]),And([Not(C1M), Not(C2M), Not(C3M), C4M, Not(C5M)]),And([Not(C1M), Not(C2M), Not(C3M), Not(C4M), C5M])])
f43 = Or([And([C1Am, Not(C2Am), Not(C3Am), Not(C4Am), Not(C5Am)]),And([Not(C1Am), C2Am, Not(C3Am), Not(C4Am), Not(C5Am)]),And([Not(C1Am), Not(C2Am), C3Am, Not(C4Am), Not(C5Am)]),And([Not(C1Am), Not(C2Am), Not(C3Am), C4Am, Not(C5Am)]),And([Not(C1Am), Not(C2Am), Not(C3Am), Not(C4Am), C5Am])])
f44 = Or([And([C1Az, Not(C2Az), Not(C3Az), Not(C4Az), Not(C5Az)]),And([Not(C1Az), C2Az, Not(C3Az), Not(C4Az), Not(C5Az)]),And([Not(C1Az), Not(C2Az), C3Az, Not(C4Az), Not(C5Az)]),And([Not(C1Az), Not(C2Az), Not(C3Az), C4Az, Not(C5Az)]),And([Not(C1Az), Not(C2Az), Not(C3Az), Not(C4Az), C5Az])])

# CADA MORADOR SÓ PODE ESTÁ EM UMA UNICA CASA:

f45 = Or([And([C1S, Not(C2S), Not(C3S), Not(C4S), Not(C5S)]),And([Not(C1S), C2S, Not(C3S), Not(C4S), Not(C5S)]),And([Not(C1S), Not(C2S), C3S, Not(C4S), Not(C5S)]),And([Not(C1S), Not(C2S), Not(C3S), C4S, Not(C5S)]),And([Not(C1S), Not(C2S), Not(C3S), Not(C4S), C5S])])
f46 = Or([And([C1Es, Not(C2Es), Not(C3Es), Not(C4Es), Not(C5Es)]),And([Not(C1Es), C2Es, Not(C3Es), Not(C4Es), Not(C5Es)]),And([Not(C1Es), Not(C2Es), C3Es, Not(C4Es), Not(C5Es)]),And([Not(C1Es), Not(C2Es), Not(C3Es), C4Es, Not(C5Es)]),And([Not(C1Es), Not(C2Es), Not(C3Es), Not(C4Es), C5Es])])
f47 = Or([And([C1Eq, Not(C2Eq), Not(C3Eq), Not(C4Eq), Not(C5Eq)]),And([Not(C1Eq), C2Eq, Not(C3Eq), Not(C4Eq), Not(C5Eq)]),And([Not(C1Eq), Not(C2Eq), C3Eq, Not(C4Eq), Not(C5Eq)]),And([Not(C1Eq), Not(C2Eq), Not(C3Eq), C4Eq, Not(C5Eq)]),And([Not(C1Eq), Not(C2Eq), Not(C3Eq), Not(C4Eq), C5Eq])])
f48 = Or([And([C1N, Not(C2N), Not(C3N), Not(C4N), Not(C5N)]),And([Not(C1N), C2N, Not(C3N), Not(C4N), Not(C5N)]),And([Not(C1N), Not(C2N), C3N, Not(C4N), Not(C5N)]),And([Not(C1N), Not(C2N), Not(C3N), C4N, Not(C5N)]),And([Not(C1N), Not(C2N), Not(C3N), Not(C4N), C5N])])
f49 = Or([And([C1J, Not(C2J), Not(C3J), Not(C4J), Not(C5J)]),And([Not(C1J), C2J, Not(C3J), Not(C4J), Not(C5J)]),And([Not(C1J), Not(C2J), C3J, Not(C4J), Not(C5J)]),And([Not(C1J), Not(C2J), Not(C3J), C4J, Not(C5J)]),And([Not(C1J), Not(C2J), Not(C3J), Not(C4J), C5J])])

# CADA ANIMAL SÓ PODE ESTÁ EM UMA UNICA CASA:

f50 = Or([And([C1C, Not(C2C), Not(C3C), Not(C4C), Not(C5C)]),And([Not(C1C), C2C, Not(C3C), Not(C4C), Not(C5C)]),And([Not(C1C), Not(C2C), C3C, Not(C4C), Not(C5C)]),And([Not(C1C), Not(C2C), Not(C3C), C4C, Not(C5C)]),And([Not(C1C), Not(C2C), Not(C3C), Not(C4C), C5C])])
f51 = Or([And([C1Esq, Not(C2Esq), Not(C3Esq), Not(C4Esq), Not(C5Esq)]),And([Not(C1Esq), C2Esq, Not(C3Esq), Not(C4Esq), Not(C5Esq)]),And([Not(C1Esq), Not(C2Esq), C3Esq, Not(C4Esq), Not(C5Esq)]),And([Not(C1Esq), Not(C2Esq), Not(C3Esq), C4Esq, Not(C5Esq)]),And([Not(C1Esq), Not(C2Esq), Not(C3Esq), Not(C4Esq), C5Esq])])
f52 = Or([And([C1R, Not(C2R), Not(C3R), Not(C4R), Not(C5R)]),And([Not(C1R), C2R, Not(C3R), Not(C4R), Not(C5R)]),And([Not(C1R), Not(C2R), C3R, Not(C4R), Not(C5R)]),And([Not(C1R), Not(C2R), Not(C3R), C4R, Not(C5R)]),And([Not(C1R), Not(C2R), Not(C3R), Not(C4R), C5R])])
f53 = Or([And([C1T, Not(C2T), Not(C3T), Not(C4T), Not(C5T)]),And([Not(C1T), C2T, Not(C3T), Not(C4T), Not(C5T)]),And([Not(C1T), Not(C2T), C3T, Not(C4T), Not(C5T)]),And([Not(C1T), Not(C2T), Not(C3T), C4T, Not(C5T)]),And([Not(C1T), Not(C2T), Not(C3T), Not(C4T), C5T])])
f54 = Or([And([C1Ca, Not(C2Ca), Not(C3Ca), Not(C4Ca), Not(C5Ca)]),And([Not(C1Ca), C2Ca, Not(C3Ca), Not(C4Ca), Not(C5Ca)]),And([Not(C1Ca), Not(C2Ca), C3Ca, Not(C4Ca), Not(C5Ca)]),And([Not(C1Ca), Not(C2Ca), Not(C3Ca), C4Ca, Not(C5Ca)]),And([Not(C1Ca), Not(C2Ca), Not(C3Ca), Not(C4Ca), C5Ca])])

# CADA BEBIDA SÓ É TOMADA EM UMA UNICA CASA:

f55 = Or([And([C1Cf, Not(C2Cf), Not(C3Cf), Not(C4Cf), Not(C5Cf)]),And([Not(C1Cf), C2Cf, Not(C3Cf), Not(C4Cf), Not(C5Cf)]),And([Not(C1Cf), Not(C2Cf), C3Cf, Not(C4Cf), Not(C5Cf)]),And([Not(C1Cf), Not(C2Cf), Not(C3Cf), C4Cf, Not(C5Cf)]),And([Not(C1Cf), Not(C2Cf), Not(C3Cf), Not(C4Cf), C5Cf])])
f56 = Or([And([C1LE, Not(C2LE), Not(C3LE), Not(C4LE), Not(C5LE)]),And([Not(C1LE), C2LE, Not(C3LE), Not(C4LE), Not(C5LE)]),And([Not(C1LE), Not(C2LE), C3LE, Not(C4LE), Not(C5LE)]),And([Not(C1LE), Not(C2LE), Not(C3LE), C4LE, Not(C5LE)]),And([Not(C1LE), Not(C2LE), Not(C3LE), Not(C4LE), C5LE])])
f57 = Or([And([C1La, Not(C2La), Not(C3La), Not(C4La), Not(C5La)]),And([Not(C1La), C2La, Not(C3La), Not(C4La), Not(C5La)]),And([Not(C1La), Not(C2La), C3La, Not(C4La), Not(C5La)]),And([Not(C1La), Not(C2La), Not(C3La), C4La, Not(C5La)]),And([Not(C1La), Not(C2La), Not(C3La), Not(C4La), C5La])])
f58 = Or([And([C1Ch, Not(C2Ch), Not(C3Ch), Not(C4Ch), Not(C5Ch)]),And([Not(C1Ch), C2Ch, Not(C3Ch), Not(C4Ch), Not(C5Ch)]),And([Not(C1Ch), Not(C2Ch), C3Ch, Not(C4Ch), Not(C5Ch)]),And([Not(C1Ch), Not(C2Ch), Not(C3Ch), C4Ch, Not(C5Ch)]),And([Not(C1Ch), Not(C2Ch), Not(C3Ch), Not(C4Ch), C5Ch])])
f59 = Or([And([C1Ag, Not(C2Ag), Not(C3Ag), Not(C4Ag), Not(C5Ag)]),And([Not(C1Ag), C2Ag, Not(C3Ag), Not(C4Ag), Not(C5Ag)]),And([Not(C1Ag), Not(C2Ag), C3Ag, Not(C4Ag), Not(C5Ag)]),And([Not(C1Ag), Not(C2Ag), Not(C3Ag), C4Ag, Not(C5Ag)]),And([Not(C1Ag), Not(C2Ag), Not(C3Ag), Not(C4Ag), C5Ag])])

# CADA INSTRUMENTO É TOCADO EM UMA UNICA CASA :

f60 = Or([And([C1Sa, Not(C2Sa), Not(C3Sa), Not(C4Sa), Not(C5Sa)]),And([Not(C1Sa), C2Sa, Not(C3Sa), Not(C4Sa), Not(C5Sa)]),And([Not(C1Sa), Not(C2Sa), C3Sa, Not(C4Sa), Not(C5Sa)]),And([Not(C1Sa), Not(C2Sa), Not(C3Sa), C4Sa, Not(C5Sa)]),And([Not(C1Sa), Not(C2Sa), Not(C3Sa), Not(C4Sa), C5Sa])])
f61 = Or([And([C1Vi, Not(C2Vi), Not(C3Vi), Not(C4Vi), Not(C5Vi)]),And([Not(C1Vi), C2Vi, Not(C3Vi), Not(C4Vi), Not(C5Vi)]),And([Not(C1Vi), Not(C2Vi), C3Vi, Not(C4Vi), Not(C5Vi)]),And([Not(C1Vi), Not(C2Vi), Not(C3Vi), C4Vi, Not(C5Vi)]),And([Not(C1Vi), Not(C2Vi), Not(C3Vi), Not(C4Vi), C5Vi])])
f62 = Or([And([C1Pi, Not(C2Pi), Not(C3Pi), Not(C4Pi), Not(C5Pi)]),And([Not(C1Pi), C2Pi, Not(C3Pi), Not(C4Pi), Not(C5Pi)]),And([Not(C1Pi), Not(C2Pi), C3Pi, Not(C4Pi), Not(C5Pi)]),And([Not(C1Pi), Not(C2Pi), Not(C3Pi), C4Pi, Not(C5Pi)]),And([Not(C1Pi), Not(C2Pi), Not(C3Pi), Not(C4Pi), C5Pi])])
f63 = Or([And([C1Ob, Not(C2Ob), Not(C3Ob), Not(C4Ob), Not(C5Ob)]),And([Not(C1Ob), C2Ob, Not(C3Ob), Not(C4Ob), Not(C5Ob)]),And([Not(C1Ob), Not(C2Ob), C3Ob, Not(C4Ob), Not(C5Ob)]),And([Not(C1Ob), Not(C2Ob), Not(C3Ob), C4Ob, Not(C5Ob)]),And([Not(C1Ob), Not(C2Ob), Not(C3Ob), Not(C4Ob), C5Ob])])
f64 = Or([And([C1At, Not(C2At), Not(C3At), Not(C4At), Not(C5At)]),And([Not(C1At), C2At, Not(C3At), Not(C4At), Not(C5At)]),And([Not(C1At), Not(C2At), C3At, Not(C4At), Not(C5At)]),And([Not(C1At), Not(C2At), Not(C3At), C4At, Not(C5At)]),And([Not(C1At), Not(C2At), Not(C3At), Not(C4At), C5At])])

# JUNTANDO TODAS AS FORMULAS QUE TEMOS:

f65 = And([f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15,f16,f17,f18,f19,f20,f21,f22,f23,f24,f25,f26,f27,f28,f29,f30,f31,f32,f33,f34,f35,f36,f37,f38,f39,f40,f41,f42,f43,f44,f45,f46,f47,f48,f49,f50,f51,f52,f53,f54,f55,f56,f57,f58,f59,f60,f61,f62,f63,f64])

s = Solver()

# Adicionando a fórmula a ser verificada
s.add(f64)

# Verificando a satisfatibilidade - o resultado deve ser sat
print(s.check())

if s.check() == sat:
# O próximo comando obtém um modelo satisfatível
  m = s.model()

# Imprimindo apenas os símbolos proposicionais verdadeiros
  for prop in m:
    if m[prop] == True:
      print(prop)
# Out:
# sat
# C2Az
# C2At
# C3LE
# C4Ob
# C4C
# C5Esq
# C1Ca
# C1Am
# C1Pi
# C2Ch
# C3R
# C1Ag
# C4Vd
# C2Eq
# C3J
# C2T
# C5La
# C3M
# C4Es
# C3Sa
# C5Vr
# C4Cf
# C5Vi
# C1N
# C5S
